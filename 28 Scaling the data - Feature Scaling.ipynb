# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path="G:\ds&ai\Visadataset.csv"
visa_df=pd.read_csv(path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# # Feature Scaling

# %% [markdown]
# ### 1. Z-score (Standardization)

# %%
# z=(x-mew)/sigma
# 99.7% of data values lies between -3 to 3 range

# %%
col=visa_df['prevailing_wage']

mean=col.mean()
std=col.std()

z_score=(col-mean)/std
visa_df['prevailing_wage_z']=z_score
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df[['prevailing_wage','prevailing_wage_z']]                        # we need to check whether the data is transformed correctly or not
# Out:
#        prevailing_wage  prevailing_wage_z
# 0             592.2029          -1.398510
# 1           83425.6500           0.169832
# 2          122996.8600           0.919060
# 3           83434.0300           0.169991
# 4          149907.3900           1.428576
# ...                ...                ...
# 25475       77092.5700           0.049923
# 25476      279174.7900           3.876083
# 25477      146298.8500           1.360253
# 25478       86154.7700           0.221504
# 25479       70876.9100          -0.067762
#
# [25480 rows x 2 columns]

# %%
visa_df['prevailing_wage'].max(),visa_df['prevailing_wage_z'].max()        # if the id's of max are same then our calculaion is correct
# Out:
# (319210.27, 4.634101837909902)

# %%
visa_df['prevailing_wage'].min(),visa_df['prevailing_wage_z'].min()
# Out:
# (2.1367, -1.4096818992891214)

# %%
visa_df['prevailing_wage'].idxmax(),visa_df['prevailing_wage_z'].idxmax()          # idxmax will give you the id of max value
# Out:
# (21077, 21077)

# %%
visa_df['prevailing_wage'].idxmin(),visa_df['prevailing_wage_z'].idxmin()
# Out:
# (20575, 20575)

# %%
visa_df[['prevailing_wage','prevailing_wage_z']].iloc[[21077,20575]]
# Out:
#        prevailing_wage  prevailing_wage_z
# 21077      319210.2700           4.634102
# 20575           2.1367          -1.409682

# %%
# generally we will overwrite the data because we want clean data for our model

# %% [markdown]
# #### StandardScaler

# %%
from sklearn.preprocessing import StandardScaler

ss=StandardScaler()

# ss.fit_transform(visa_df['prevailing_wage'])                  # this o/p is a series type so we are unable to store in a variable

visa_df['prevailing_wage_ss']=ss.fit_transform(visa_df[['prevailing_wage']])

# %%
visa_df[['prevailing_wage','prevailing_wage_z','prevailing_wage_ss']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 visa_df[['prevailing_wage','prevailing_wage_z','prevailing_wage_ss']]
#
# File ~\anaconda3.0\Lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3.0\Lib\site-packages\pandas\core\indexes\base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
#    5880 if isinstance(key, Index):
# ...

# %% [markdown]
# ### 2. min-max scalar (Normalization)

# %%
# minmax = (x - x_min)/(x_max - x_min)
# range from -1 to 1

# %%
path="G:\ds&ai\Visadataset.csv"
visa_df=pd.read_csv(path)

# %%
col=visa_df['prevailing_wage']

min_max=(col-col.min())/(col.max()-col.min())
visa_df['prevailing_wage_minmax']=min_max

# %%
visa_df[['prevailing_wage','prevailing_wage_minmax']]
# Out:
#        prevailing_wage  prevailing_wage_minmax
# 0             592.2029                0.001849
# 1           83425.6500                0.261345
# 2          122996.8600                0.385312
# 3           83434.0300                0.261371
# 4          149907.3900                0.469616
# ...                ...                     ...
# 25475       77092.5700                0.241505
# 25476      279174.7900                0.874579
# 25477      146298.8500                0.458311
# 25478       86154.7700                0.269895
# 25479       70876.9100                0.222033
#
# [25480 rows x 2 columns]

# %%
visa_df['prevailing_wage'].max(),visa_df['prevailing_wage_minmax'].max()
# Out:
# (319210.27, 1.0)

# %%
visa_df['prevailing_wage'].idxmax(),visa_df['prevailing_wage_minmax'].idxmax()
# Out:
# (21077, 21077)

# %%
visa_df['prevailing_wage'].min(),visa_df['prevailing_wage_minmax'].min()
# Out:
# (2.1367, 0.0)

# %%
visa_df['prevailing_wage'].idxmin(),visa_df['prevailing_wage_minmax'].idxmin()
# Out:
# (20575, 20575)

# %% [markdown]
# #### min max scaler

# %%
from sklearn.preprocessing import MinMaxScaler

mms=MinMaxScaler()

visa_df['prevailing_wage_mms']=mms.fit_transform(visa_df[['prevailing_wage']])

# %%
visa_df[['prevailing_wage','prevailing_wage_minmax','prevailing_wage_mms']]
# Out:
#        prevailing_wage  prevailing_wage_minmax  prevailing_wage_mms
# 0             592.2029                0.001849             0.001849
# 1           83425.6500                0.261345             0.261345
# 2          122996.8600                0.385312             0.385312
# 3           83434.0300                0.261371             0.261371
# 4          149907.3900                0.469616             0.469616
# ...                ...                     ...                  ...
# 25475       77092.5700                0.241505             0.241505
# 25476      279174.7900                0.874579             0.874579
# 25477      146298.8500                0.458311             0.458311
# 25478       86154.7700                0.269895             0.269895
# 25479       70876.9100                0.222033             0.222033
#
# [25480 rows x 3 columns]

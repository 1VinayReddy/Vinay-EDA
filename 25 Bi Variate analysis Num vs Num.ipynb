# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path="G:\ds&ai\Visadataset.csv"
visa_df=pd.read_csv(path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# ## Numerical v/s Numerical

# %%
x=[1,2,3,4,5]
y=[1,2,3,4,5]

# to plot this use scatter plot

# %% [markdown]
# #### plt.scatter

# %%
plt.scatter(x,y)                 # plots the points

# %%
plt.scatter(x,y)
plt.plot(x,y)                             # marks the line 
plt.show()

# %%
x=[i for i in range(-4,5)]
y=[i*i for i in x]

plt.scatter(x,y)
plt.plot(x,y)
plt.show()

# %% [markdown]
# ## Correlation

# %%
num_cols=visa_df.select_dtypes(exclude='object')
num_cols.columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
# select any 2 columns from these 3

col1=visa_df['no_of_employees']
col2=visa_df['prevailing_wage']

plt.scatter(col1,col2)
plt.show()

# %%
# to understand the relation between col1,col2 we need correlation
# in python correlation is printed as matrix 
# Matrix size is nxn where n= no. of  numerical columns

# %%
visa_df.corr(numeric_only=True)
# Out:
#                  no_of_employees  yr_of_estab  prevailing_wage
# no_of_employees         1.000000    -0.017770        -0.009523
# yr_of_estab            -0.017770     1.000000         0.012342
# prevailing_wage        -0.009523     0.012342         1.000000

# %%
# value close to 1 -> highly related or dependent (directly related)
# value close to 0 -> almost independent or not related
# value close to -1 -> highly related or dependent (inversely related)

# %%
col1=visa_df['yr_of_estab']
col2=visa_df['prevailing_wage']

plt.scatter(col1,col2)

# %%
path="G:\ds&ai\winequality_red.csv"
wine_df=pd.read_csv(path)
wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               NaN               NaN          NaN             NaN        NaN
# 1               7.4             0.700         0.00             1.9      0.076
# 2               NaN               NaN          NaN             NaN        NaN
# 3               7.8             0.880         0.00             2.6      0.098
# 4               NaN               NaN          NaN             NaN        NaN
# ...             ...               ...          ...             ...        ...
# 3193            6.3             0.510         0.13             2.3      0.076
# 3194            NaN               NaN          NaN             NaN        NaN
# 3195            5.9             0.645         0.12             2.0      0.075
# 3196            NaN               NaN          NaN             NaN        NaN
# 3197            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
wine_df.select_dtypes(exclude='object')
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               NaN               NaN          NaN             NaN        NaN
# 1               7.4             0.700         0.00             1.9      0.076
# 2               NaN               NaN          NaN             NaN        NaN
# 3               7.8             0.880         0.00             2.6      0.098
# 4               NaN               NaN          NaN             NaN        NaN
# ...             ...               ...          ...             ...        ...
# 3193            6.3             0.510         0.13             2.3      0.076
# 3194            NaN               NaN          NaN             NaN        NaN
# 3195            5.9             0.645         0.12             2.0      0.075
# 3196            NaN               NaN          NaN             NaN        NaN
# 3197            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
wine_df.corr(numeric_only=True)
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
wine_df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
# fixed acidity vs citric acid has correlation value=0.67...
# directly related

col1=wine_df['fixed acidity']
col2=wine_df['citric acid']

plt.scatter(col1,col2)
plt.show()

# %%
# fixed acidity vs pH has correlation value= -0.68...
# inversely related

col1=wine_df['fixed acidity']
col2=wine_df['pH']

plt.scatter(col1,col2)
plt.show()

# %%
# with df.corr() the only problem is when the no. of columns are more
# if we have 1000 columns what can we do???

# so we use heatmap

# %% [markdown]
# ## Heatmap

# %%
# It is a visualization of correlation matrix
# In seaborn package
# Change in color represents change in value of correlation matrix

# %%
corr_visa=visa_df.corr(numeric_only=True)
corr_visa
# Out:
#                  no_of_employees  yr_of_estab  prevailing_wage
# no_of_employees         1.000000    -0.017770        -0.009523
# yr_of_estab            -0.017770     1.000000         0.012342
# prevailing_wage        -0.009523     0.012342         1.000000

# %%
sns.heatmap(corr_visa)         # sns.heatmap(<correlation matrix>)
# Out:
# <Axes: >

# %%
sns.heatmap(corr_visa,annot=True)            # annot means annotation 
plt.show()

# %%
corr_wine=wine_df.corr(numeric_only=True)
corr_wine
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
plt.figure(figsize=(12,10))
sns.heatmap(corr_wine,annot=True)
plt.show()

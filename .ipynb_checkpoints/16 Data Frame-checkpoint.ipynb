# %%
# I am modifying this code!!!

# %% [markdown]
# # Reading CSV files

# %%
import pandas as pd                       # Dataframe operations
import numpy as np                        # Math operations
import matplotlib.pyplot as plt           # Plots or diagrams
import seaborn as sns                     # Plots or diagrams

# %% [markdown]
# ##### pd.read_csv()

# %%
new_path=r"G:\ds&ai\bank .csv"
pd.read_csv(new_path)
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
"""
After the data reading step "pd.read_csv(path)" all the data is in a single column, 
open the dataset and see which character is separating the column's data.

If the character is ';' then use "pd.read_csv(path,sep=';')"
"""
# Out:
# '\nAfter the data reading step "pd.read_csv(path)" all the data is in a single column, \nopen the dataset and see which character is separating the column\'s data.\n\nIf the character is \';\' then use "pd.read_csv(path,sep=\';\')"\n'

# %%
path="G:\\ds&ai\\Visadataset.csv"
pd.read_csv(path)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
path=r"G:\ds&ai\bank .csv"
pd.read_csv(path)
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
path=r"G:\ds&ai\bank .csv"
pd.read_csv(path,header=None) # header = None -> column names row is also considered as a row
# Out:
#        0              1        2          3        4        5        6     7   \
# 0     age            job  marital  education  default  balance  housing  loan
# 1      30     unemployed  married    primary       no     1787       no    no
# 2      33       services  married  secondary       no     4789      yes   yes
# 3      35     management   single   tertiary       no     1350      yes    no
# 4      30     management  married   tertiary       no     1476      yes   yes
# ...   ...            ...      ...        ...      ...      ...      ...   ...
# 4517   33       services  married  secondary       no     -333      yes    no
# 4518   57  self-employed  married   tertiary      yes    -3313      yes   yes
# 4519   57     technician  married  secondary       no      295       no    no
# 4520   28    blue-collar  married  secondary       no     1137       no    no
# 4521   44   entrepreneur   single   tertiary       no     1136      yes   yes
#
# ...

# %% [markdown]
# # Create dataframe using list

# %%
name=['vinay','jb','bachi']
age=[21,22,21]

# %%
name,age
# Out:
# (['vinay', 'jb', 'bachi'], [21, 22, 21])

# %% [markdown]
# #### Provide Data

# %%
vjb=pd.DataFrame(zip(name,age))           # Creates dataframe
vjb
# Out:
#        0   1
# 0  vinay  21
# 1     jb  22
# 2  bachi  21

# %% [markdown]
# #### Naming Columns

# %%
dataa=zip(name,age)
vjb=pd.DataFrame(dataa,columns=["Name","Age"])
vjb
# Out:
#     Name  Age
# 0  vinay   21
# 1     jb   22
# 2  bachi   21

# %%
data_file=zip(name,age)
column_names=['name','age']
vjb=pd.DataFrame(data_file,columns=column_names)
vjb
# Out:
#     name  age
# 0  vinay   21
# 1     jb   22
# 2  bachi   21

# %% [markdown]
# #### Giving indexes

# %%
dataa=zip(name,age)
vjb=pd.DataFrame(dataa,columns=["Name","Age"],index=[1,2,3])
vjb
# Out:
#     Name  Age
# 1  vinay   21
# 2     jb   22
# 3  bachi   21

# %%
dataa=zip(name,age)
index_order=['a','b','c']
vjb=pd.DataFrame(dataa,columns=["Name","Age"],index=index_order)
vjb
# Out:
#     Name  Age
# a  vinay   21
# b     jb   22
# c  bachi   21

# %% [markdown]
# #### Adding new columns

# %%
area_names=['Habsiguda','Tarnaka','Habsiguda']
vjb['place']=area_names
vjb
# Out:
#     Name  Age      place
# a  vinay   21  Habsiguda
# b     jb   22    Tarnaka
# c  bachi   21  Habsiguda

# %% [markdown]
# #### Updating the exesting columns

# %%
vjb['Name']
# Out:
# a    vinay
# b       jb
# c    bachi
# Name: Name, dtype: object

# %%
vjb['Name']=['Vinay','Jayanand','Bhaskar']
vjb
# Out:
#        Name  Age      place
# a     Vinay   21  Habsiguda
# b  Jayanand   22    Tarnaka
# c   Bhaskar   21  Habsiguda

# %%
surname=['R.','B.','N.']
vjb['Surnames']=surname
vjb
# Out:
#        Name  Age      place Surnames
# a     Vinay   21  Habsiguda       R.
# b  Jayanand   22    Tarnaka       B.
# c   Bhaskar   21  Habsiguda       N.

# %% [markdown]
# #### Dropping a column

# %%
VJB=vjb.drop('Surnames',axis=1)                                # if "inplace=True" is not mentioned then the dataframe will not get updated
VJB                                                            # if axis = 0 -> it means row
                                                               # if axis = 1 -> it means column
# or 

vjb.drop('Surnames',axis=1,inplace=True)
vjb
# Out:
#        Name  Age      place
# a     Vinay   21  Habsiguda
# b  Jayanand   22    Tarnaka
# c   Bhaskar   21  Habsiguda

# %% [markdown]
# #### Dropping Row

# %%
vjb.drop('a',axis=0,inplace=True)                         # deletes 1st row
vjb
# Out:
#        Name  Age      place
# b  Jayanand   22    Tarnaka
# c   Bhaskar   21  Habsiguda

# %% [markdown]
# #### Save the dataframe

# %%
vjb.to_csv("G:\\ds&ai\\vjb.csv")                            # give the path -> then name of the file -> then extension type

# %%
path="G:\\ds&ai\\vjb.csv"
file=pd.read_csv(path)                                      # Index that we gave is considered as extra column while saving
file
# Out:
#   Unnamed: 0      Name  Age      place
# 0          b  Jayanand   22    Tarnaka
# 1          c   Bhaskar   21  Habsiguda

# %%
# to avoid the above problem give "index = False"

# vjb.to_csv("G:\\ds&ai\\vjb.csv",index=False)
# pd.read_csv("G:\\ds&ai\\vjb.csv")

# %% [markdown]
# # Creating Dataframe using Dictionary

# %%
d1={"name":['vinay','jayanand','bhaskar'],
    "age":[21,22,21]}
VJB=pd.DataFrame(d1)
VJB
# Out:
#        name  age
# 0     vinay   21
# 1  jayanand   22
# 2   bhaskar   21
